# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/dataset/train (4).csv')
test=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/dataset/test (3).csv')
train.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
train['keyword'].value_counts()
# Out:
# keyword
# fatalities               45
# deluge                   42
# armageddon               42
# sinking                  41
# damage                   41
#                          ..
# forest%20fire            19
# epicentre                12
# threat                   11
# inundation               10
# radiation%20emergency     9
# Name: count, Length: 221, dtype: int64

# %%
train.shape
# Out:
# (7613, 5)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
test['target']=9

# %%
df=pd.concat([train,test],axis=0)
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.isnull().sum()
# Out:
# id             0
# keyword       87
# location    3638
# text           0
# target         0
# dtype: int64

# %%
#df['keyword'] = df['keyword'].fillna(df['keyword'].mode()[0])
#df['location'] = df['location'].fillna(df['location'].mode()[0])

# %%
#df.isnull().sum()

# %%
df.drop(['keyword','location','id'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# text      0
# target    0
# dtype: int64

# %%
df['target'].value_counts()
# Out:
# target
# 0    4342
# 1    3271
# 9    3263
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (10876, 2)

# %%
df.head()
# Out:
#                                                 text  target
# 0  Our Deeds are the Reason of this #earthquake M...       1
# 1             Forest fire near La Ronge Sask. Canada       1
# 2  All residents asked to 'shelter in place' are ...       1
# 3  13,000 people receive #wildfires evacuation or...       1
# 4  Just got sent this photo from Ruby #Alaska as ...       1

# %%
test = df[df['target']==9]
train = df[df['target']!=9]

# %%
x=train.drop('target',axis=1)
y=train['target']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()
x=cv.fit_transform(x['text'])

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# target
# 1    4342
# 0    4342
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#from sklearn.linear_model import LogisticRegression
#from sklearn.ensemble import RandomForestClassifier

# %%
#lr=LogisticRegression()
#lr.fit(x_train,y_train)

# %%
#pred=lr.predict(x_test)

# %%
from sklearn.metrics import classification_report
#print(classification_report(y_test,pred))

# %%
#lr.score(x_test,y_test),lr.score(x_train,y_train)

# %%
from sklearn.naive_bayes import BernoulliNB
nb=BernoulliNB()
nb.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
pred=nb.predict(x_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.82       858
#            1       0.83      0.80      0.81       879
#
#     accuracy                           0.81      1737
#    macro avg       0.81      0.81      0.81      1737
# weighted avg       0.81      0.81      0.81      1737

# %%
nb.score(x_test,y_test),nb.score(x_train,y_train)
# Out:
# (0.8146229130685089, 0.9048510148265438)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred=gb.predict(x_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.76      0.74       858
#            1       0.75      0.70      0.72       879
#
#     accuracy                           0.73      1737
#    macro avg       0.73      0.73      0.73      1737
# weighted avg       0.73      0.73      0.73      1737

# %%
gb.score(x_test,y_test),gb.score(x_train,y_train)
# Out:
# (0.7305699481865285, 0.742046926730963)

# %%
test.head()
# Out:
#                                                 text  target
# 0                 Just happened a terrible car crash       9
# 1  Heard about #earthquake is different cities, s...       9
# 2  there is a forest fire at spot pond, geese are...       9
# 3           Apocalypse lighting. #Spokane #wildfires       9
# 4      Typhoon Soudelor kills 28 in China and Taiwan       9

# %%
test.drop('target',axis=1,inplace=True)
# Out:
# <ipython-input-116-4be4be5cf6bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.drop('target',axis=1,inplace=True)

# %%
test.head()
# Out:
#                                                 text
# 0                 Just happened a terrible car crash
# 1  Heard about #earthquake is different cities, s...
# 2  there is a forest fire at spot pond, geese are...
# 3           Apocalypse lighting. #Spokane #wildfires
# 4      Typhoon Soudelor kills 28 in China and Taiwan

# %%
test=cv.transform(test['text'])

# %%
test_pred=nb.predict(test)
test_pred=pd.DataFrame(test_pred)
test_pred
# Out:
#       0
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 3258  1
# 3259  1
# 3260  1
# 3261  1
# 3262  1
#
# [3263 rows x 1 columns]

# %%
sub=pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/dataset/sample_submission (1).csv')
sub.head()
# Out:
#    id  target
# 0   0       0
# 1   2       0
# 2   3       0
# 3   9       0
# 4  11       0

# %%
sub['target']=test_pred
sub.head()
# Out:
#    id  target
# 0   0       1
# 1   2       1
# 2   3       1
# 3   9       1
# 4  11       1

# %%
sub.to_csv('submission.csv',index=False)

# %%
from google.colab import files
files.download('submission.csv')
